# %% [markdown]
# # Simulation

# %% [markdown]
# The simulator allows to observe the behavior of the system under a given policy.
#
# The following policies are provided:

# %%
import stochastic_matching as sm
sm.common.get_classes(sm.Simulator)
# Out:
# {'fcfm': stochastic_matching.simulator.fcfm.FCFM,
#  'priority': stochastic_matching.simulator.priority.Priority,
#  'random_edge': stochastic_matching.simulator.random_edge.RandomEdge,
#  'random_item': stochastic_matching.simulator.random_item.RandomItem,
#  'e_filtering': stochastic_matching.simulator.e_filtering.EFiltering,
#  'longest': stochastic_matching.simulator.longest.Longest,
#  'virtual_queue': stochastic_matching.simulator.virtual_queue.VirtualQueue}

# %% [markdown]
# NB: only simple graphs are considered in the present notebook.

# %% [markdown]
# ## Tadpole

# %% [markdown]
# ### Bijective

# %% [markdown]
# Consider the following tadpole:

# %%
from stochastic_matching.display import VIS_OPTIONS
VIS_OPTIONS['height'] = 300
tadpole = sm.Tadpole(m=5, n=3, rates='uniform')
tadpole.show_graph()
# Out:
# <div id="63f67127-0f21-4fee-9546-07b5a6aaa03b"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "0", "title": "0"}, {"id": 1, "label": "1", "title": "1"}, {"id": 2, "label": "2", "title": "2"}, {"id": 3, "label": "3", "title": "3"}, {"id": 4, "label": "4", "title": "4"}, {"id": 5, "label": "5", "title": "5"}, {"id": 6, "label": "6", "title": "6"}, {"id": 7, "label": "7", "title": "7"}];
# var edges = [{"title": "0: (0, 1)", "label": "", "from": 0, "to": 1}, {"title": "1: (0, 4)", "label": "", "from": 0, "to": 4}, {"title": "2: (1, 2)", "label": "", "from": 1, "to": 2}, {"title": "3: (2, 3)", "label": "", "from": 2, "to": 3}, {"title": "4: (3, 4)", "label": "", "from": 3, "to": 4}, {"title": "5: (4, 5)", "label": "", "from": 4, "to": 5}, {"title": "6: (5, 6)", "label": "", "from": 5, "to": 6}, {"title": "7: (6, 7)", "label": "", "from": 6, "to": 7}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('63f67127-0f21-4fee-9546-07b5a6aaa03b');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# This tadpole is not stabilizable: it is bijective and its unique solution has null edges.

# %%
tadpole.show_flow()
# Out:
# <div id="e7fc063d-67d2-464f-aaf8-6ee3573baf32"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0"}, {"id": 1, "label": "1", "title": "1"}, {"id": 2, "label": "1", "title": "2"}, {"id": 3, "label": "1", "title": "3"}, {"id": 4, "label": "1", "title": "4"}, {"id": 5, "label": "1", "title": "5"}, {"id": 6, "label": "1", "title": "6"}, {"id": 7, "label": "1", "title": "7"}];
# var edges = [{"title": "0: (0, 1)", "label": "1", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 4)", "label": "0", "color": "orange", "from": 0, "to": 4}, {"title": "2: (1, 2)", "label": "0", "color": "orange", "from": 1, "to": 2}, {"title": "3: (2, 3)", "label": "1", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 4)", "label": "0", "color": "orange", "from": 3, "to": 4}, {"title": "5: (4, 5)", "label": "1", "color": "blue", "from": 4, "to": 5}, {"title": "6: (5, 6)", "label": "0", "color": "orange", "from": 5, "to": 6}, {"title": "7: (6, 7)", "label": "1", "color": "blue", "from": 6, "to": 7}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('e7fc063d-67d2-464f-aaf8-6ee3573baf32');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# As a consequence, the system is unstable.

# %%
tadpole.run('fcfm', n_steps=10000000)
# Out:
# False

# %% [markdown]
# The simulator finished before the end (due to queue overflow).

# %%
tadpole.simulator.logs.steps_done
# Out:
# 906433

# %%
tadpole.show_flow()
# Out:
# <div id="fee4636d-206e-4403-84d3-2f7ac25a7c8a"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0"}, {"id": 1, "label": "1", "title": "1"}, {"id": 2, "label": "1", "title": "2"}, {"id": 3, "label": "1", "title": "3"}, {"id": 4, "label": "1", "title": "4"}, {"id": 5, "label": "1", "title": "5"}, {"id": 6, "label": "1", "title": "6"}, {"id": 7, "label": "1", "title": "7"}];
# var edges = [{"title": "0: (0, 1)", "label": "0.995", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 4)", "label": "0.00387", "color": "blue", "from": 0, "to": 4}, {"title": "2: (1, 2)", "label": "0.00691", "color": "blue", "from": 1, "to": 2}, {"title": "3: (2, 3)", "label": "0.99", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 4)", "label": "0.00197", "color": "blue", "from": 3, "to": 4}, {"title": "5: (4, 5)", "label": "0.989", "color": "blue", "from": 4, "to": 5}, {"title": "6: (5, 6)", "label": "0.0104", "color": "blue", "from": 5, "to": 6}, {"title": "7: (6, 7)", "label": "0.99", "color": "blue", "from": 6, "to": 7}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('fee4636d-206e-4403-84d3-2f7ac25a7c8a');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# We can look the CCDFs of the run to see what went wrong:

# %%
fig = tadpole.simulator.show_ccdf(sort=True)

# %% [markdown]
# Node 7 overflowed, while node 5 was not in a good shape either.

# %% [markdown]
# This can also be showed with average queue sizes:

# %%
fig = tadpole.simulator.show_average_queues(sort=True)

# %% [markdown]
# Let's change the arrival rates to have something nicer.

# %%
tadpole.rates = [1, 1, 1, 1, 2, 2, 2, 1]

# %% [markdown]
# We can see that it works!

# %%
tadpole.run('fcfm', n_steps=10000000)
# Out:
# True

# %%
tadpole.show_flow()
# Out:
# <div id="af21190f-55d8-4969-9ba2-c71c5f091cd2"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0"}, {"id": 1, "label": "1", "title": "1"}, {"id": 2, "label": "1", "title": "2"}, {"id": 3, "label": "1", "title": "3"}, {"id": 4, "label": "2", "title": "4"}, {"id": 5, "label": "2", "title": "5"}, {"id": 6, "label": "2", "title": "6"}, {"id": 7, "label": "1", "title": "7"}];
# var edges = [{"title": "0: (0, 1)", "label": "0.5", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 4)", "label": "0.501", "color": "blue", "from": 0, "to": 4}, {"title": "2: (1, 2)", "label": "0.499", "color": "blue", "from": 1, "to": 2}, {"title": "3: (2, 3)", "label": "0.501", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 4)", "label": "0.499", "color": "blue", "from": 3, "to": 4}, {"title": "5: (4, 5)", "label": "1", "color": "blue", "from": 4, "to": 5}, {"title": "6: (5, 6)", "label": "0.998", "color": "blue", "from": 5, "to": 6}, {"title": "7: (6, 7)", "label": "0.999", "color": "blue", "from": 6, "to": 7}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('af21190f-55d8-4969-9ba2-c71c5f091cd2');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# We can see that the queues are much more tight!

# %%
fig = tadpole.simulator.show_average_queues(sort=True)

# %% [markdown]
# Note that the average queue can be converted in an average waiting time.

# %%
fig = tadpole.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# ### Nonjective

# %% [markdown]
# Consider the following tadpole:

# %%
tadpole = sm.Tadpole(rates='uniform', m=4)

# %% [markdown]
# It is bipartite and does not verify the stability condition NCond (even bipartite NCond), so all solution break the conservation law.

# %% [markdown]
# Simulation fails:

# %%
tadpole.run('fcfm', n_steps=10000000, max_queue=100000)
# Out:
# False

# %%
tadpole.show_flow()
# Out:
# <div id="df04d081-bab5-4ad7-bf72-0799b5bb07be"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0", "color": "red"}, {"id": 1, "label": "1", "title": "1"}, {"id": 2, "label": "1", "title": "2", "color": "red"}, {"id": 3, "label": "1", "title": "3"}, {"id": 4, "label": "1", "title": "4", "color": "red"}];
# var edges = [{"title": "0: (0, 1)", "label": "0.502", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 3)", "label": "0.165", "color": "blue", "from": 0, "to": 3}, {"title": "2: (1, 2)", "label": "0.5", "color": "blue", "from": 1, "to": 2}, {"title": "3: (2, 3)", "label": "0.165", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 4)", "label": "0.668", "color": "blue", "from": 3, "to": 4}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('df04d081-bab5-4ad7-bf72-0799b5bb07be');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# Nodes 0, 2, and 4 are in limbo.

# %%
fig = tadpole.simulator.show_average_queues()

# %% [markdown]
# Let's change the arrival rates to have bipartite NCond (which is not non-bipartite NCond).

# %%
tadpole.rates = [1, 1, 1, 2, 1]

# %%
tadpole.run('fcfm', n_steps=1000000)
# Out:
# True

# %% [markdown]
# We can see that it works! FCFM seems to stabilizes even if NCond is not met.

# %%
tadpole.show_flow()
# Out:
# <div id="7c59747f-3ba5-4f76-8b0f-7f6ad7145646"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0"}, {"id": 1, "label": "1", "title": "1"}, {"id": 2, "label": "1", "title": "2"}, {"id": 3, "label": "2", "title": "3"}, {"id": 4, "label": "1", "title": "4"}];
# var edges = [{"title": "0: (0, 1)", "label": "0.5", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 3)", "label": "0.497", "color": "blue", "from": 0, "to": 3}, {"title": "2: (1, 2)", "label": "0.502", "color": "blue", "from": 1, "to": 2}, {"title": "3: (2, 3)", "label": "0.499", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 4)", "label": "0.998", "color": "blue", "from": 3, "to": 4}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('7c59747f-3ba5-4f76-8b0f-7f6ad7145646');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %%
fig = tadpole.simulator.show_ccdf()

# %% [markdown]
# Hum, the queues are quite high. Maybe we didn't wait long enough?

# %%
tadpole.run('fcfm', n_steps=10000000, seed=42)
# Out:
# False

# %%
fig = tadpole.simulator.show_ccdf()

# %% [markdown]
# Not so stable after all... This is not surprising because of the random walk between left and right nodes, which forces queues of arbitrary size if one waits long enough.

# %% [markdown]
# ## Diamond

# %% [markdown]
# Consider the following:

# %%
diamond = sm.CycleChain(tol=1e-3)
ϵ = 0.2
diamond.rates = [2, 2+ϵ, 1+ϵ, 1]

# %% [markdown]
# Try fcfm

# %%
diamond.run('fcfm', n_steps=10000000)
# Out:
# True

# %%
diamond.show_flow()
# Out:
# <div id="7101ea1d-72e3-4d5f-bf08-463d2de72149"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "1.33", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0.668", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.199", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0.665", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "0.334", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('7101ea1d-72e3-4d5f-bf08-463d2de72149');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# Nodes 0 and 3 are non-empty most of the time.

# %%
fig = diamond.simulator.show_ccdf()

# %%
fig = diamond.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# Try random edge (we use a seed to have a True result; in practice, random node is highly borderline in this example and overflows relatively often).

# %%
diamond.run('random_edge', n_steps=10000000, seed=42)
# Out:
# True

# %%
diamond.show_flow()
# Out:
# <div id="91a0924a-3f83-41cf-a6b5-1018f7b4e5a0"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "1.33", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0.667", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.199", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0.667", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "0.333", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('91a0924a-3f83-41cf-a6b5-1018f7b4e5a0');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %%
fig = diamond.simulator.show_ccdf()

# %%
fig = diamond.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# Try random item.

# %%
diamond.run('random_item', n_steps=10000000)
# Out:
# True

# %%
diamond.show_flow()
# Out:
# <div id="c82dc9a8-aead-4c2a-ab77-9f3909326b3e"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "1.33", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0.668", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.198", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0.666", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "0.333", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('c82dc9a8-aead-4c2a-ab77-9f3909326b3e');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %%
fig = diamond.simulator.show_ccdf()

# %%
fig = diamond.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# ### Trying to reach an extreme feasible solution with a greedy policy

# %% [markdown]
# Now we would like to have a greedy policy that tries to move on towards the extreme feasible solutions. Sadly, no such policy exists (cf https://hal.archives-ouvertes.fr/hal-03502084).

# %% [markdown]
# Yet, we can try to approach them with priority-based greedy selection. First, look at the extreme points (vertices).

# %%
diamond = sm.CycleChain(rates=[2, 2.2, 1.2, 1])
for i in range(len(diamond.vertices)):
    diamond.show_vertex(i)
# Out:
# <div id="f876d7b9-19b4-4f85-a576-15dcb46d76a8"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "1", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "1", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.2", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "1", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "", "color": "orange", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('f876d7b9-19b4-4f85-a576-15dcb46d76a8');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>
# <div id="2f84801c-7e99-4eac-bd98-83d48ab51a23"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "2", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "", "color": "orange", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.2", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "", "color": "orange", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "1", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('2f84801c-7e99-4eac-bd98-83d48ab51a23');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# We can see that the first vertex prioritizes edges 1 and 3, while the second one prioritizes edges 0 and 4. Let us see what happens if one uses these priorities in a greedy policy.

# %%
diamond.run('priority', weights=[0, 1, 0, 1, 0], n_steps=10000000)
diamond.show_flow()
# Out:
# <div id="5c8499a0-d554-47f2-9cb9-6e70240fb39d"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "1.07", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0.933", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.2", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0.931", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "0.0693", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('5c8499a0-d554-47f2-9cb9-6e70240fb39d');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %%
diamond.run('priority', weights=[1, 0, 0, 0, 1], n_steps=10000000)
diamond.show_flow()
# Out:
# <div id="ed38d79f-e02d-4bfd-a0c2-1a51322e805e"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "1.73", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0.272", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.198", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0.27", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "0.73", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('ed38d79f-e02d-4bfd-a0c2-1a51322e805e');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# Not bad, but not perfect. To reach a vertex, we may need to use a filtering policy.

# %% [markdown]
# ### Trying to reach an extreme feasible solution with a filtering policy

# %%
diamond.vertices
# Out:
# [{'kernel_coordinates': array([-0.25]),
#   'edge_coordinates': array([1. , 1. , 0.2, 1. , 0. ]),
#   'null_edges': [4],
#   'bijective': True},
#  {'kernel_coordinates': array([0.75]),
#   'edge_coordinates': array([2. , 0. , 0.2, 0. , 1. ]),
#   'null_edges': [1, 3],
#   'bijective': False}]

# %% [markdown]
# The first kernel is bijective, we just need to forbid the null edge.

# %%
diamond.run('longest', forbidden_edges=diamond.vertices[0]['null_edges'], n_steps=10000000)
# Out:
# True

# %%
diamond.show_flow()
# Out:
# <div id="9f0c4de3-a301-4b51-a623-2db490db3207"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "1", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0.999", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.202", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0.999", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "0", "color": "orange", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('9f0c4de3-a301-4b51-a623-2db490db3207');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# We can check that the matching rate on edge 4 is 0.

# %%
diamond.simulation
# Out:
# array([1.00047808, 0.99915264, 0.20158848, 0.99878016, 0.        ])

# %% [markdown]
# No noticeable impact on the performance.

# %%
fig = diamond.simulator.show_ccdf()

# %%
fig = diamond.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# Now we try on the second kernel.

# %%
diamond.run('longest', forbidden_edges=diamond.vertices[1]['null_edges'], n_steps=10000000)
# Out:
# False

# %%
diamond.show_flow()
# Out:
# <div id="0003c762-bead-4683-80da-9c275920f8d4"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "2", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0", "color": "orange", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.2", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0", "color": "orange", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "0.999", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('0003c762-bead-4683-80da-9c275920f8d4');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# So this is unstable but the the matching rate on edges 1 and 3 is 0.

# %%
diamond.simulation
# Out:
# array([1.99957622, 0.        , 0.20045326, 0.        , 0.99910573])

# %% [markdown]
# Performance is bad, as the vertex is injective-only (bipartite).

# %%
fig = diamond.simulator.show_ccdf()

# %%
fig = diamond.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# The solution in that case is to use a k-filtering policy (i.e. with threshold).

# %%
diamond.run('longest', forbidden_edges=diamond.vertices[1]['null_edges'], k=500, n_steps=10000000)
# Out:
# True

# %%
diamond.show_flow()
# Out:
# <div id="ab802fcc-4096-4de8-9afc-c37fbee6a8c8"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "2", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0.00153", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.2", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0.000197", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "0.999", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('ab802fcc-4096-4de8-9afc-c37fbee6a8c8');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# So this is stable with a limited matching rate on edges 1 and 3.

# %%
diamond.simulation
# Out:
# array([1.9995712e+00, 1.5276800e-03, 1.9951488e-01, 1.9712000e-04,
#        9.9900160e-01])

# %% [markdown]
# Performance is controlled by the threshold.

# %%
fig = diamond.simulator.show_ccdf()

# %%
fig = diamond.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# ### Reward maximization variant

# %% [markdown]
# In many use cases, one may want to optimize the flow based on some reward associated to each edge. It turns out that this equivalent to finding a subset of edges to forbid such that the flow(s) on that subgraph will maximize the reward. `stochastic_matching` automatically implements this in two ways:
# - It gives an optimal flow associated to a vector of rewards;
# - the filtering policy can take a vector of rewards as arguments and automatically discard the null edges of one optimal solution.

# %%
rewards = [2, 1, 2, 1, 2]
diamond.optimize_rates(rewards)
# Out:
# array([2. , 0. , 0.2, 0. , 1. ])

# %%
diamond.run('longest', rewards=rewards, k=300, forbidden_edges=True)
# Out:
# True

# %%
diamond.show_flow()
# Out:
# <div id="08f1c342-a52c-4cc7-8fde-a8956da030da"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "2.2", "title": "1"}, {"id": 2, "label": "1.2", "title": "2"}, {"id": 3, "label": "1", "title": "3"}];
# var edges = [{"title": "0: (0, 1)", "label": "2", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "0.00243", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.199", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 3)", "label": "0.000672", "color": "blue", "from": 1, "to": 3}, {"title": "4: (2, 3)", "label": "1", "color": "blue", "from": 2, "to": 3}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('08f1c342-a52c-4cc7-8fde-a8956da030da');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %%
fig = diamond.simulator.show_ccdf()

# %%
fig = diamond.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# ## Fish

# %% [markdown]
# The purpose of this example is to show a case where a family of greedy with priorities can asymptotically reach the vertices.

# %%
fish = sm.KayakPaddle(l=0, m=4, names=[str(i) for i in range(1, 7)], rates = [4, 4, 3, 2, 3, 2])
fish.show_graph()
# Out:
# <div id="d7c1db2a-7394-449d-bb76-1ceba76d7fda"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0: 1"}, {"id": 1, "label": "2", "title": "1: 2"}, {"id": 2, "label": "3", "title": "2: 3"}, {"id": 3, "label": "4", "title": "3: 4"}, {"id": 4, "label": "5", "title": "4: 5"}, {"id": 5, "label": "6", "title": "5: 6"}];
# var edges = [{"title": "0: (1, 2)", "label": "", "from": 0, "to": 1}, {"title": "1: (1, 3)", "label": "", "from": 0, "to": 2}, {"title": "2: (2, 3)", "label": "", "from": 1, "to": 2}, {"title": "3: (3, 4)", "label": "", "from": 2, "to": 3}, {"title": "4: (3, 6)", "label": "", "from": 2, "to": 5}, {"title": "5: (4, 5)", "label": "", "from": 3, "to": 4}, {"title": "6: (5, 6)", "label": "", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('d7c1db2a-7394-449d-bb76-1ceba76d7fda');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# Look at the vertices:

# %%
for i in range(len(fish.vertices)):
    fish.show_vertex(i, disp_rates=False)
# Out:
# <div id="acae7d7f-6f51-423d-9052-cba05565a87f"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0: 1"}, {"id": 1, "label": "2", "title": "1: 2"}, {"id": 2, "label": "3", "title": "2: 3"}, {"id": 3, "label": "4", "title": "3: 4"}, {"id": 4, "label": "5", "title": "4: 5"}, {"id": 5, "label": "6", "title": "5: 6"}];
# var edges = [{"title": "0: (1, 2)", "label": "3", "color": "blue", "from": 0, "to": 1}, {"title": "1: (1, 3)", "label": "1", "color": "blue", "from": 0, "to": 2}, {"title": "2: (2, 3)", "label": "1", "color": "blue", "from": 1, "to": 2}, {"title": "3: (3, 4)", "label": "", "color": "orange", "from": 2, "to": 3}, {"title": "4: (3, 6)", "label": "1", "color": "blue", "from": 2, "to": 5}, {"title": "5: (4, 5)", "label": "2", "color": "blue", "from": 3, "to": 4}, {"title": "6: (5, 6)", "label": "1", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('acae7d7f-6f51-423d-9052-cba05565a87f');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>
# <div id="07606dbb-6c8b-432b-9efe-a48dc12cc26a"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0: 1"}, {"id": 1, "label": "2", "title": "1: 2"}, {"id": 2, "label": "3", "title": "2: 3"}, {"id": 3, "label": "4", "title": "3: 4"}, {"id": 4, "label": "5", "title": "4: 5"}, {"id": 5, "label": "6", "title": "5: 6"}];
# var edges = [{"title": "0: (1, 2)", "label": "3", "color": "blue", "from": 0, "to": 1}, {"title": "1: (1, 3)", "label": "1", "color": "blue", "from": 0, "to": 2}, {"title": "2: (2, 3)", "label": "1", "color": "blue", "from": 1, "to": 2}, {"title": "3: (3, 4)", "label": "1", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 6)", "label": "", "color": "orange", "from": 2, "to": 5}, {"title": "5: (4, 5)", "label": "1", "color": "blue", "from": 3, "to": 4}, {"title": "6: (5, 6)", "label": "2", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('07606dbb-6c8b-432b-9efe-a48dc12cc26a');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# Let us try to nullify the edge between 3 and 6 with adapted priorities. As this may be unstable, let us pick a large max queue.

# %%
rewards = [0, 2, 2, 1, 0, 0, 1]
fish.run('priority', weights=rewards, n_steps=10000000, max_queue=1000000)
# Out:
# True

# %%
fish.show_flow(disp_rates=False)
# Out:
# <div id="9493e5f1-cb3e-4b1c-ba6a-f98a774d875f"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0: 1"}, {"id": 1, "label": "2", "title": "1: 2"}, {"id": 2, "label": "3", "title": "2: 3"}, {"id": 3, "label": "4", "title": "3: 4", "color": "red"}, {"id": 4, "label": "5", "title": "4: 5"}, {"id": 5, "label": "6", "title": "5: 6"}];
# var edges = [{"title": "0: (1, 2)", "label": "2.91", "color": "blue", "from": 0, "to": 1}, {"title": "1: (1, 3)", "label": "1.09", "color": "blue", "from": 0, "to": 2}, {"title": "2: (2, 3)", "label": "1.09", "color": "blue", "from": 1, "to": 2}, {"title": "3: (3, 4)", "label": "0.821", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 6)", "label": "3.6e-06", "color": "blue", "from": 2, "to": 5}, {"title": "5: (4, 5)", "label": "0.996", "color": "blue", "from": 3, "to": 4}, {"title": "6: (5, 6)", "label": "2", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('9493e5f1-cb3e-4b1c-ba6a-f98a774d875f');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# So we managed to almost nullify the edge at the price of making node 4 unstable (it cannot check the conservation law). This can be addressed by using a threshold above which the policy is altered.

# %%
counterweights = [0, 1, 1, 2, 0, 0, 2]

# %%
fish.run('priority', weights=rewards, n_steps=10000000, threshold=500, counterweights=counterweights)
# Out:
# True

# %%
fish.show_flow(disp_rates=False)
# Out:
# <div id="a265047f-7b07-44a5-8159-67683ad49ebe"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0: 1"}, {"id": 1, "label": "2", "title": "1: 2"}, {"id": 2, "label": "3", "title": "2: 3"}, {"id": 3, "label": "4", "title": "3: 4"}, {"id": 4, "label": "5", "title": "4: 5"}, {"id": 5, "label": "6", "title": "5: 6"}];
# var edges = [{"title": "0: (1, 2)", "label": "3", "color": "blue", "from": 0, "to": 1}, {"title": "1: (1, 3)", "label": "1", "color": "blue", "from": 0, "to": 2}, {"title": "2: (2, 3)", "label": "1", "color": "blue", "from": 1, "to": 2}, {"title": "3: (3, 4)", "label": "0.999", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 6)", "label": "2.34e-05", "color": "blue", "from": 2, "to": 5}, {"title": "5: (4, 5)", "label": "1", "color": "blue", "from": 3, "to": 4}, {"title": "6: (5, 6)", "label": "2", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('a265047f-7b07-44a5-8159-67683ad49ebe');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# And that's it! The threshold controls the trade-off between the size of queue 4 and the nullity of edge (3, 6).

# %%
fig = fish.simulator.show_ccdf()

# %%
fig = fish.simulator.show_average_queues()

# %%
fish.run('priority', weights=rewards, n_steps=10000000, threshold=10, counterweights=counterweights)
# Out:
# True

# %%
fish.show_flow(disp_rates=False)
# Out:
# <div id="e20e5760-6be3-4efe-af1c-9f2d16aac692"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0: 1"}, {"id": 1, "label": "2", "title": "1: 2"}, {"id": 2, "label": "3", "title": "2: 3"}, {"id": 3, "label": "4", "title": "3: 4"}, {"id": 4, "label": "5", "title": "4: 5"}, {"id": 5, "label": "6", "title": "5: 6"}];
# var edges = [{"title": "0: (1, 2)", "label": "3", "color": "blue", "from": 0, "to": 1}, {"title": "1: (1, 3)", "label": "1", "color": "blue", "from": 0, "to": 2}, {"title": "2: (2, 3)", "label": "1", "color": "blue", "from": 1, "to": 2}, {"title": "3: (3, 4)", "label": "0.965", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 6)", "label": "0.0342", "color": "blue", "from": 2, "to": 5}, {"title": "5: (4, 5)", "label": "1.03", "color": "blue", "from": 3, "to": 4}, {"title": "6: (5, 6)", "label": "1.96", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('e20e5760-6be3-4efe-af1c-9f2d16aac692');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# And that's it! The threshold controls the trade-off between the size of queue 4 and the nullity of edge (3, 6).

# %%
fig = fish.simulator.show_ccdf()

# %%
fig = fish.simulator.show_average_queues()

# %% [markdown]
# Last possibility: use a reward-based greedy scoring.

# %%
fish.run('longest', rewards=rewards, n_steps=10000000, beta=.01, shift_rewards=True)
# Out:
# True

# %%
fish.show_flow(disp_rates=False)
# Out:
# <div id="31c903db-9298-4060-8c7b-74ccfe082e60"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0: 1"}, {"id": 1, "label": "2", "title": "1: 2"}, {"id": 2, "label": "3", "title": "2: 3"}, {"id": 3, "label": "4", "title": "3: 4"}, {"id": 4, "label": "5", "title": "4: 5"}, {"id": 5, "label": "6", "title": "5: 6"}];
# var edges = [{"title": "0: (1, 2)", "label": "3", "color": "blue", "from": 0, "to": 1}, {"title": "1: (1, 3)", "label": "0.999", "color": "blue", "from": 0, "to": 2}, {"title": "2: (2, 3)", "label": "1", "color": "blue", "from": 1, "to": 2}, {"title": "3: (3, 4)", "label": "0.994", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 6)", "label": "0.000353", "color": "blue", "from": 2, "to": 5}, {"title": "5: (4, 5)", "label": "1", "color": "blue", "from": 3, "to": 4}, {"title": "6: (5, 6)", "label": "2", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('31c903db-9298-4060-8c7b-74ccfe082e60');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# And that's it! Beta controls the trade-off between the size of queue 4 and the nullity of edge (3, 6).

# %%
fig = fish.simulator.show_ccdf()

# %%
fig = fish.simulator.show_average_queues()

# %%
fish.run('longest', rewards=rewards, n_steps=10000000, beta=.1, shift_rewards=True)
# Out:
# True

# %%
fish.show_flow(disp_rates=False)
# Out:
# <div id="3ecacbeb-8c11-4612-b077-ab1fd770ccbd"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "1", "title": "0: 1"}, {"id": 1, "label": "2", "title": "1: 2"}, {"id": 2, "label": "3", "title": "2: 3"}, {"id": 3, "label": "4", "title": "3: 4"}, {"id": 4, "label": "5", "title": "4: 5"}, {"id": 5, "label": "6", "title": "5: 6"}];
# var edges = [{"title": "0: (1, 2)", "label": "3", "color": "blue", "from": 0, "to": 1}, {"title": "1: (1, 3)", "label": "0.994", "color": "blue", "from": 0, "to": 2}, {"title": "2: (2, 3)", "label": "1", "color": "blue", "from": 1, "to": 2}, {"title": "3: (3, 4)", "label": "0.98", "color": "blue", "from": 2, "to": 3}, {"title": "4: (3, 6)", "label": "0.0235", "color": "blue", "from": 2, "to": 5}, {"title": "5: (4, 5)", "label": "1.02", "color": "blue", "from": 3, "to": 4}, {"title": "6: (5, 6)", "label": "1.98", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('3ecacbeb-8c11-4612-b077-ab1fd770ccbd');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# And that's it! Beta controls the trade-off between the size of queue 4 and the nullity of edge (3, 6).

# %%
fig = fish.simulator.show_ccdf()

# %%
fig = fish.simulator.show_average_queues()

# %% [markdown]
# ## Reaching a highly degenerated vertex

# %% [markdown]
# The following model has *very injective* vertices.

# %%
import numpy as np
codomino = sm.Codomino(rates=[2, 4, 2, 2, 4, 2])
codomino.base_flow = np.array([1.0, 1.0, 1.0, 2.0, 0.0, 1.0, 1.0, 1.0])
codomino.vertices
# Out:
# [{'kernel_coordinates': array([-1., -1.]),
#   'edge_coordinates': array([0., 2., 0., 4., 0., 0., 2., 0.]),
#   'null_edges': [0, 2, 4, 5, 7],
#   'bijective': False},
#  {'kernel_coordinates': array([-1.,  1.]),
#   'edge_coordinates': array([2., 0., 0., 2., 2., 0., 0., 2.]),
#   'null_edges': [1, 2, 5, 6],
#   'bijective': False},
#  {'kernel_coordinates': array([1., 1.]),
#   'edge_coordinates': array([2., 0., 2., 0., 0., 2., 0., 2.]),
#   'null_edges': [1, 3, 4, 6],
#   'bijective': False}]

# %% [markdown]
# In particular the first vertex is made of three unconnected pairs:

# %%
codomino.show_vertex(0)
# Out:
# <div id="770ab107-6546-4dea-b4fc-d62108597db3"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "4", "title": "1"}, {"id": 2, "label": "2", "title": "2"}, {"id": 3, "label": "2", "title": "3"}, {"id": 4, "label": "4", "title": "4"}, {"id": 5, "label": "2", "title": "5"}];
# var edges = [{"title": "0: (0, 1)", "label": "", "color": "orange", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "2", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "", "color": "orange", "from": 1, "to": 2}, {"title": "3: (1, 4)", "label": "4", "color": "blue", "from": 1, "to": 4}, {"title": "4: (2, 3)", "label": "", "color": "orange", "from": 2, "to": 3}, {"title": "5: (3, 4)", "label": "", "color": "orange", "from": 3, "to": 4}, {"title": "6: (3, 5)", "label": "2", "color": "blue", "from": 3, "to": 5}, {"title": "7: (4, 5)", "label": "", "color": "orange", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('770ab107-6546-4dea-b4fc-d62108597db3');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# Let try to reach it with a filtering policy without threshold.

# %%
codomino.run('longest', forbidden_edges=codomino.vertices[0]['null_edges'], n_steps=10000000, max_queue=100000)
# Out:
# True

# %%
codomino.show_flow()
# Out:
# <div id="e9604778-0a83-4c0f-ad8a-e7c51de0889a"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "4", "title": "1"}, {"id": 2, "label": "2", "title": "2"}, {"id": 3, "label": "2", "title": "3"}, {"id": 4, "label": "4", "title": "4"}, {"id": 5, "label": "2", "title": "5"}];
# var edges = [{"title": "0: (0, 1)", "label": "0", "color": "orange", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "2", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0", "color": "orange", "from": 1, "to": 2}, {"title": "3: (1, 4)", "label": "4", "color": "blue", "from": 1, "to": 4}, {"title": "4: (2, 3)", "label": "0", "color": "orange", "from": 2, "to": 3}, {"title": "5: (3, 4)", "label": "0", "color": "orange", "from": 3, "to": 4}, {"title": "6: (3, 5)", "label": "2", "color": "blue", "from": 3, "to": 5}, {"title": "7: (4, 5)", "label": "0", "color": "orange", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('e9604778-0a83-4c0f-ad8a-e7c51de0889a');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# As this is pure filtering, the desired edges are indeed null.

# %%
codomino.simulation
# Out:
# array([0.       , 1.9977536, 0.       , 3.9996384, 0.       , 0.       ,
#        2.0006656, 0.       ])

# %% [markdown]
# But performance is awful!

# %%
fig = codomino.simulator.show_ccdf()

# %%
fig = codomino.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# A solution in that case is to use a $k$-filtering policy (i.e. with threshold).

# %%
codomino.run('longest', forbidden_edges=codomino.vertices[0]['null_edges'], k=900, n_steps=10000000)
# Out:
# True

# %%
codomino.show_flow()
# Out:
# <div id="f517ff17-2dd8-4c9d-a88a-53476117b1f0"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "4", "title": "1"}, {"id": 2, "label": "2", "title": "2"}, {"id": 3, "label": "2", "title": "3"}, {"id": 4, "label": "4", "title": "4"}, {"id": 5, "label": "2", "title": "5"}];
# var edges = [{"title": "0: (0, 1)", "label": "0.00307", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "2", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0", "color": "orange", "from": 1, "to": 2}, {"title": "3: (1, 4)", "label": "4", "color": "blue", "from": 1, "to": 4}, {"title": "4: (2, 3)", "label": "0", "color": "orange", "from": 2, "to": 3}, {"title": "5: (3, 4)", "label": "0.00293", "color": "blue", "from": 3, "to": 4}, {"title": "6: (3, 5)", "label": "2", "color": "blue", "from": 3, "to": 5}, {"title": "7: (4, 5)", "label": "0.00373", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('f517ff17-2dd8-4c9d-a88a-53476117b1f0');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %% [markdown]
# So this is stable with a limited matching rate on forbidden edges.

# %%
codomino.simulation
# Out:
# array([3.0672000e-03, 1.9972304e+00, 0.0000000e+00, 3.9954352e+00,
#        0.0000000e+00, 2.9280000e-03, 1.9968848e+00, 3.7328000e-03])

# %% [markdown]
# Performance is controlled by the threshold.

# %%
fig = codomino.simulator.show_ccdf()

# %%
fig = codomino.simulator.show_average_queues(sort=True, as_time=True)

# %%
codomino.run('longest', forbidden_edges=codomino.vertices[0]['null_edges'], k=50, n_steps=10000000)
# Out:
# True

# %%
codomino.show_flow()
# Out:
# <div id="0a4b2181-af32-4088-acce-d1e2c7cca526"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "4", "title": "1"}, {"id": 2, "label": "2", "title": "2"}, {"id": 3, "label": "2", "title": "3"}, {"id": 4, "label": "4", "title": "4"}, {"id": 5, "label": "2", "title": "5"}];
# var edges = [{"title": "0: (0, 1)", "label": "0.0444", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "1.95", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.0306", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 4)", "label": "3.93", "color": "blue", "from": 1, "to": 4}, {"title": "4: (2, 3)", "label": "0.0123", "color": "blue", "from": 2, "to": 3}, {"title": "5: (3, 4)", "label": "0.0333", "color": "blue", "from": 3, "to": 4}, {"title": "6: (3, 5)", "label": "1.96", "color": "blue", "from": 3, "to": 5}, {"title": "7: (4, 5)", "label": "0.0435", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('0a4b2181-af32-4088-acce-d1e2c7cca526');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %%
codomino.simulation
# Out:
# array([0.0443776, 1.9524512, 0.0306336, 3.9258976, 0.0123232, 0.0332736,
#        1.9575072, 0.0435152])

# %%
fig = codomino.simulator.show_ccdf()

# %%
fig = codomino.simulator.show_average_queues(sort=True, as_time=True)

# %% [markdown]
# Other filtering policies exists:

# %%
codomino.run('e_filtering', forbidden_edges=codomino.vertices[0]['null_edges'], epsilon=.01, n_steps=10000000)
# Out:
# True

# %%
codomino.show_flow()
# Out:
# <div id="e945d560-c04c-405b-bee3-8bdd9974525f"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "4", "title": "1"}, {"id": 2, "label": "2", "title": "2"}, {"id": 3, "label": "2", "title": "3"}, {"id": 4, "label": "4", "title": "4"}, {"id": 5, "label": "2", "title": "5"}];
# var edges = [{"title": "0: (0, 1)", "label": "0.0276", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "1.97", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.0203", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 4)", "label": "3.95", "color": "blue", "from": 1, "to": 4}, {"title": "4: (2, 3)", "label": "0.00981", "color": "blue", "from": 2, "to": 3}, {"title": "5: (3, 4)", "label": "0.0194", "color": "blue", "from": 3, "to": 4}, {"title": "6: (3, 5)", "label": "1.97", "color": "blue", "from": 3, "to": 5}, {"title": "7: (4, 5)", "label": "0.0277", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('e945d560-c04c-405b-bee3-8bdd9974525f');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %%
codomino.simulation
# Out:
# array([0.027568 , 1.9696768, 0.0203312, 3.9526368, 0.0098112, 0.0194064,
#        1.9728544, 0.0276576])

# %%
fig = codomino.simulator.show_ccdf()

# %%
fig = codomino.simulator.show_average_queues(sort=True, as_time=True)

# %%
rewards = [1 * (i not in codomino.vertices[0]['null_edges']) for i in range(8)]
rewards
# Out:
# [0, 1, 0, 1, 0, 0, 1, 0]

# %%
codomino.run('virtual_queue', rewards=rewards, beta=.01, n_steps=10000000)
# Out:
# True

# %%
codomino.show_flow()
# Out:
# <div id="0d24f05e-d83e-4217-9f4e-8fac5673c556"></div>
# <script>
# require.config({
#     paths: {
#         vis: 'https://unpkg.com/vis-network/standalone/umd/vis-network.min'
#     }
# });
# require(['vis'], function(vis){
# var nodes = [{"id": 0, "label": "2", "title": "0"}, {"id": 1, "label": "4", "title": "1"}, {"id": 2, "label": "2", "title": "2"}, {"id": 3, "label": "2", "title": "3"}, {"id": 4, "label": "4", "title": "4"}, {"id": 5, "label": "2", "title": "5"}];
# var edges = [{"title": "0: (0, 1)", "label": "0.00829", "color": "blue", "from": 0, "to": 1}, {"title": "1: (0, 2)", "label": "1.99", "color": "blue", "from": 0, "to": 2}, {"title": "2: (1, 2)", "label": "0.00593", "color": "blue", "from": 1, "to": 2}, {"title": "3: (1, 4)", "label": "3.98", "color": "blue", "from": 1, "to": 4}, {"title": "4: (2, 3)", "label": "0.00328", "color": "blue", "from": 2, "to": 3}, {"title": "5: (3, 4)", "label": "0.00931", "color": "blue", "from": 3, "to": 4}, {"title": "6: (3, 5)", "label": "1.99", "color": "blue", "from": 3, "to": 5}, {"title": "7: (4, 5)", "label": "0.0106", "color": "blue", "from": 4, "to": 5}];
# var data= {
#     nodes: nodes,
#     edges: edges,
# };
# var options = {"interaction": {"navigationButtons": true}, "width": "600px", "height": 300};
# var container = document.getElementById('0d24f05e-d83e-4217-9f4e-8fac5673c556');
# var network = new vis.Network(container, data, options);
# network.fit({
#   maxZoomLevel: 1000});
# });
# </script>

# %%
codomino.simulation
# Out:
# array([8.2896000e-03, 1.9915008e+00, 5.9280000e-03, 3.9822880e+00,
#        3.2800000e-03, 9.3072000e-03, 1.9884384e+00, 1.0620800e-02])

# %%
fig = codomino.simulator.show_ccdf()

# %%
fig = codomino.simulator.show_average_queues(sort=True, as_time=True)
